# %% [markdown]
# <a href="https://colab.research.google.com/github/Navin7899/ABC-Tech/blob/main/ABC_Tech.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymysql
# !pip install mysql-connector
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 1.7 MB/s eta 0:00:00
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 17.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for mysql-connector: filename=mysql_connector-2.2.9-cp38-cp38-linux_x86_64.whl size=247965 sha256=2fe397f804520f1be0cc13ab00181412b403a87b20d3f868375111281cda8398
#   Stored in directory: /root/.cache/pip/wheels/57/e4/98/5feafb5c393dd2540e44b064a6f95832990d543e5b4f53ea8f
# Successfully built mysql-connector
# ...

# %%
import os
import mysql.connector
import pandas as pd
import numpy as np

# %%
connection=mysql.connector.connect(host = '18.136.157.135',user='dm_team', port='3306',password='DM!$Team@&27920!')

# %%
cursor=connection.cursor()
cursor.execute('show databases')
for i in cursor:
    print(i)
# Out:
# ('information_schema',)
# ('project_itsm',)

# %%
connection=mysql.connector.connect(host = '18.136.157.135',user='dm_team', port='3306',password='DM!$Team@&27920!',database='project_itsm')

# %%
db_tables=pd.read_sql_query('show tables',connection)
print(db_tables)
# Out:
#   Tables_in_project_itsm
# 0           dataset_list

# %%
query = "select * from dataset_list" # SQL statement
output = pd.read_sql(query,connection)
print(output.shape)
output
# Out:
# (46606, 25)
#          CI_Name          CI_Cat                 CI_Subcat        WBS  \
# 0      SUB000508  subapplication     Web Based Application  WBS000162
# 1      WBA000124     application     Web Based Application  WBS000088
# 2      DTA000024     application       Desktop Application  WBS000092
# 3      WBA000124     application     Web Based Application  WBS000088
# 4      WBA000124     application     Web Based Application  WBS000088
# ...          ...             ...                       ...        ...
# 46601  SBA000464     application  Server Based Application  WBS000073
# 46602  SBA000461     application  Server Based Application  WBS000073
# 46603  LAP000019        computer                    Laptop  WBS000091
# 46604  WBA000058     application     Web Based Application  WBS000073
# 46605  DCE000077        hardware       DataCenterEquipment  WBS000267
#
#       Incident_ID  Status Impact Urgency Priority   number_cnt  ...  \
# ...

# %%
pd.set_option("display.max_columns",25)

# %%
output.head(10)
# Out:
#      CI_Name          CI_Cat              CI_Subcat        WBS Incident_ID  \
# 0  SUB000508  subapplication  Web Based Application  WBS000162   IM0000004
# 1  WBA000124     application  Web Based Application  WBS000088   IM0000005
# 2  DTA000024     application    Desktop Application  WBS000092   IM0000006
# 3  WBA000124     application  Web Based Application  WBS000088   IM0000011
# 4  WBA000124     application  Web Based Application  WBS000088   IM0000012
# 5  WBA000124     application  Web Based Application  WBS000088   IM0000013
# 6  WBA000082     application  Web Based Application  WBS000055   IM0000014
# 7  WBA000124     application  Web Based Application  WBS000088   IM0000015
# 8  WBA000124     application  Web Based Application  WBS000088   IM0000017
# 9  WBA000082     application  Web Based Application  WBS000055   IM0000018
#
#    Status Impact Urgency Priority   number_cnt                 Category  \
# ...

# %%
def value_count(df):
  for column in df:
    print()
    print('The value counts of {} column is'.format('\033[1m'+ column + '\033[0m'))
    print()
    print(df[column].value_counts())
    print('------------------------------------------------------------------')

# %%
value_count(output)
# Out:
# The value counts of CI_Name column is
#
# SUB000456    3050
# SBA000263    2176
# SBA000607    1743
# SBA000462    1698
# WBA000058    1614
#              ...
# LAP001572       1
# LAP000809       1
# LAP000513       1
# CBD000266       1
# SWT000008       1
# Name: CI_Name, Length: 3019, dtype: int64
# ------------------------------------------------------------------
#
# The value counts of CI_Cat column is
#
# application             32900
# subapplication           7782
# computer                 3643
# storage                   703
# hardware                  442
# software                  333
# database                  214
# displaydevice             212
# officeelectronics         152
#                           111
# networkcomponents         107
# applicationcomponent        5
# Phone                       2
# Name: CI_Cat, dtype: int64
# ------------------------------------------------------------------
#
# The value counts of CI_Subcat column is
#
# ...

# %%
def space(df):
  for column in df:
    df[column] = df[column].str.replace(r'[\x00-\x19]', '').replace('', 'miss')
    if output[column].str.contains('miss').any():
       print('Total {} replacement happened for {} column '.format(df[column].value_counts()['miss'],column))

# %%
space(output)
# Out:
# <ipython-input-12-cc012f4de9b4>:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df[column] = df[column].str.replace(r'[\x00-\x19]', '').replace('', 'miss')
# Total 111 replacement happened for CI_Cat column
# Total 111 replacement happened for CI_Subcat column
# Total 1 replacement happened for No_of_Reassignments column
# Total 44322 replacement happened for Reopen_Time column
# Total 1780 replacement happened for Resolved_Time column
# Total 1 replacement happened for Handle_Time_hrs column
# Total 460 replacement happened for Closure_Code column
# Total 114 replacement happened for No_of_Related_Interactions column
# Total 45384 replacement happened for No_of_Related_Incidents column
# Total 46046 replacement happened for No_of_Related_Changes column
# Total 46046 replacement happened for Related_Change column
